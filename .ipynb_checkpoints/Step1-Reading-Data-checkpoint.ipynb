# %%
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import zipfile

# %% [markdown]
# # Step 1: Reading the data
#
# The database used here is the [Flowers-299](https://www.kaggle.com/datasets/bogdancretu/flower299/) kaggle dataset. \
# To run this notebook download the dataset from there and save it as 'images.zip'

# %%
data = []
with zipfile.ZipFile('images.zip') as f:
    for name in f.namelist():
        _, class_name, filename = name.split('/')
        img = Image.open(f.open(name))
        data.append({"Class": class_name, "Filename": filename, "Img": img})
df = pd.DataFrame.from_dict(data)
df
# Out:
#            Class        Filename  \
# 0       Abutilon  0008688612.jpg
# 1       Abutilon  0081bf4b7a.jpg
# 2       Abutilon  008e7e9310.jpg
# 3       Abutilon  02621a076a.jpg
# 4       Abutilon  04f51e35e6.jpg
# ...          ...             ...
# 115939    Zinnia  fcf44357b7.jpg
# 115940    Zinnia  fcf4ac45dd.jpg
# 115941    Zinnia  fe58fd8623.jpg
# 115942    Zinnia  fe8ee7bb5e.jpg
# 115943    Zinnia  feb697c5e2.jpg
#
#                                                       Img
# 0       <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1       <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2       <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3       <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 4       <PIL.JpegImagePlugin.JpegImageFile image mode=...
# ...                                                   ...
# 115939  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 115940  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 115941  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 115942  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 115943  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
# [115944 rows x 3 columns]

# %%
# Print out a few samples, to check that the images are read correctly.
for _, row in df.sample(n=3).iterrows():
    plt.imshow(row['Img'])
    plt.title('Class: ' + row['Class'] + ', file: ' + row['Filename'] )
    plt.show()
